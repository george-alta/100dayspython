# %%
import math
import collections
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
planets = pd.read_csv('./Planets2.csv')

# %%
planets
# Out:
#     Planet       Mass Diameter  DayLength  SunDistance OrbitPeriod
# 0  MERCURY     0.3300     4879     4222.6         57.9          88  \
# 1    VENUS     4.8700   12,104     2802.0        108.2       224.7
# 2    EARTH     5.9700   12,756       24.0        149.6       365.2
# 3     MOON     0.0730     3475      708.7          NaN        27.3
# 4     MARS     0.6420     6792       24.7        227.9         687
# 5  JUPITER  1898.0000  142,984        9.9        778.6        4331
# 6   SATURN   568.0000  120,536       10.7       1433.5      10,747
# 7   URANUS    86.8000   51,118       17.2       2872.5      30,589
# 8  NEPTUNE   102.0000   49,528       16.1       4495.1      59,800
# 9    PLUTO     0.0146     2370      153.3       5906.4      90,560
#
#    OrbitVelocity  MeanTemperature  SurfacePressure  Moons Rings MagneticField
# 0           47.4              167          0.00000      0    No           Yes  \
# 1           35.0              464         92.00000      0    No            No
# 2           29.8               15          1.00000      1    No           Yes
# 3            1.0              -20          0.00000      0    No            No
# 4           24.1              -65          0.01000      2    No            No
# 5           13.1             -110              NaN     67   Yes           Yes
# 6            9.7             -140              NaN     62   Yes           Yes
# 7            6.8             -195              NaN     27   Yes           Yes
# 8            5.4             -200              NaN     14   Yes           Yes
# 9            4.7             -225          0.00001      5    No           NaN
#
#   FirstVisited  FirstMission
# 0   1974-03-29    Mariner 10
# 1   1962-08-27     Mariner 2
# 2          NaN           NaN
# 3   1959-09-12        Luna 2
# 4   1965-07-15     Mariner 4
# 5   1973-12-04    Pioneer 10
# 6   1979-09-01    Pioneer 11
# 7   1986-01-24     Voyager 2
# 8   1989-08-25     Voyager 2
# 9   2015-07-14  New Horizons

# %%
planets = pd.read_csv('./Planets2.csv', usecols=[0,1,2,3])

# %%
planets
# Out:
#     Planet       Mass Diameter  DayLength
# 0  MERCURY     0.3300     4879     4222.6
# 1    VENUS     4.8700   12,104     2802.0
# 2    EARTH     5.9700   12,756       24.0
# 3     MOON     0.0730     3475      708.7
# 4     MARS     0.6420     6792       24.7
# 5  JUPITER  1898.0000  142,984        9.9
# 6   SATURN   568.0000  120,536       10.7
# 7   URANUS    86.8000   51,118       17.2
# 8  NEPTUNE   102.0000   49,528       16.1
# 9    PLUTO     0.0146     2370      153.3

# %%
planets['Mass']
# Out:
# 0       0.3300
# 1       4.8700
# 2       5.9700
# 3       0.0730
# 4       0.6420
# 5    1898.0000
# 6     568.0000
# 7      86.8000
# 8     102.0000
# 9       0.0146
# Name: Mass, dtype: float64

# %%
planets.Mass
# Out:
# 0       0.3300
# 1       4.8700
# 2       5.9700
# 3       0.0730
# 4       0.6420
# 5    1898.0000
# 6     568.0000
# 7      86.8000
# 8     102.0000
# 9       0.0146
# Name: Mass, dtype: float64

# %%
planets.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
planets.loc[0]
# Out:
# Planet       MERCURY
# Mass            0.33
# Diameter        4879
# DayLength     4222.6
# Name: 0, dtype: object

# %%
planets.set_index('Planet', inplace=True)

# %%
planets
# Out:
#               Mass Diameter  DayLength
# Planet
# MERCURY     0.3300     4879     4222.6
# VENUS       4.8700   12,104     2802.0
# EARTH       5.9700   12,756       24.0
# MOON        0.0730     3475      708.7
# MARS        0.6420     6792       24.7
# JUPITER  1898.0000  142,984        9.9
# SATURN    568.0000  120,536       10.7
# URANUS     86.8000   51,118       17.2
# NEPTUNE   102.0000   49,528       16.1
# PLUTO       0.0146     2370      153.3

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, MERCURY to PLUTO
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Mass       10 non-null     float64
#  1   Diameter   10 non-null     object
#  2   DayLength  10 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 320.0+ bytes

# %%
len(planets)
# Out:
# 10

# %%
planets.loc['MERCURY']
# Out:
# Mass           0.33
# Diameter       4879
# DayLength    4222.6
# Name: MERCURY, dtype: object

# %%
planets.loc['MERCURY':'EARTH']
# Out:
#          Mass Diameter  DayLength
# Planet
# MERCURY  0.33     4879     4222.6
# VENUS    4.87   12,104     2802.0
# EARTH    5.97   12,756       24.0

# %%
planets.columns
# Out:
# Index(['Mass', 'Diameter', 'DayLength'], dtype='object')

# %%
planets = pd.read_csv('./Planets2.csv')

# %%
planets.set_index('Planet',inplace=True)

# %%
planets
# Out:
#               Mass Diameter  DayLength  SunDistance OrbitPeriod
# Planet
# MERCURY     0.3300     4879     4222.6         57.9          88  \
# VENUS       4.8700   12,104     2802.0        108.2       224.7
# EARTH       5.9700   12,756       24.0        149.6       365.2
# MOON        0.0730     3475      708.7          NaN        27.3
# MARS        0.6420     6792       24.7        227.9         687
# JUPITER  1898.0000  142,984        9.9        778.6        4331
# SATURN    568.0000  120,536       10.7       1433.5      10,747
# URANUS     86.8000   51,118       17.2       2872.5      30,589
# NEPTUNE   102.0000   49,528       16.1       4495.1      59,800
# PLUTO       0.0146     2370      153.3       5906.4      90,560
#
#          OrbitVelocity  MeanTemperature  SurfacePressure  Moons Rings
# Planet
# MERCURY           47.4              167          0.00000      0    No  \
# VENUS             35.0              464         92.00000      0    No
# EARTH             29.8               15          1.00000      1    No
# MOON               1.0              -20          0.00000      0    No
# MARS              24.1              -65          0.01000      2    No
# JUPITER           13.1             -110              NaN     67   Yes
# SATURN             9.7             -140              NaN     62   Yes
# URANUS             6.8             -195              NaN     27   Yes
# NEPTUNE            5.4             -200              NaN     14   Yes
# PLUTO              4.7             -225          0.00001      5    No
#
#         MagneticField FirstVisited  FirstMission
# Planet
# MERCURY           Yes   1974-03-29    Mariner 10
# VENUS              No   1962-08-27     Mariner 2
# EARTH             Yes          NaN           NaN
# MOON               No   1959-09-12        Luna 2
# MARS               No   1965-07-15     Mariner 4
# JUPITER           Yes   1973-12-04    Pioneer 10
# SATURN            Yes   1979-09-01    Pioneer 11
# URANUS            Yes   1986-01-24     Voyager 2
# NEPTUNE           Yes   1989-08-25     Voyager 2
# PLUTO             NaN   2015-07-14  New Horizons

# %%
planets.FirstVisited['MERCURY']
# Out:
# '1974-03-29'

# %%
planets.loc['MERCURY'].FirstVisited
# Out:
# '1974-03-29'

# %%
planets.loc['MERCURY','FirstVisited']
# Out:
# '1974-03-29'

# %%
type(planets.loc['MERCURY','FirstVisited'])
# Out:
# str

# %%
pd.to_datetime(planets.FirstVisited)
# Out:
# Planet
# MERCURY   1974-03-29
# VENUS     1962-08-27
# EARTH            NaT
# MOON      1959-09-12
# MARS      1965-07-15
# JUPITER   1973-12-04
# SATURN    1979-09-01
# URANUS    1986-01-24
# NEPTUNE   1989-08-25
# PLUTO     2015-07-14
# Name: FirstVisited, dtype: datetime64[ns]

# %%
planets.FirstVisited = pd.to_datetime(planets.FirstVisited)

# %%
planets
# Out:
#               Mass Diameter  DayLength  SunDistance OrbitPeriod
# Planet
# MERCURY     0.3300     4879     4222.6         57.9          88  \
# VENUS       4.8700   12,104     2802.0        108.2       224.7
# EARTH       5.9700   12,756       24.0        149.6       365.2
# MOON        0.0730     3475      708.7          NaN        27.3
# MARS        0.6420     6792       24.7        227.9         687
# JUPITER  1898.0000  142,984        9.9        778.6        4331
# SATURN    568.0000  120,536       10.7       1433.5      10,747
# URANUS     86.8000   51,118       17.2       2872.5      30,589
# NEPTUNE   102.0000   49,528       16.1       4495.1      59,800
# PLUTO       0.0146     2370      153.3       5906.4      90,560
#
#          OrbitVelocity  MeanTemperature  SurfacePressure  Moons Rings
# Planet
# MERCURY           47.4              167          0.00000      0    No  \
# VENUS             35.0              464         92.00000      0    No
# EARTH             29.8               15          1.00000      1    No
# MOON               1.0              -20          0.00000      0    No
# MARS              24.1              -65          0.01000      2    No
# JUPITER           13.1             -110              NaN     67   Yes
# SATURN             9.7             -140              NaN     62   Yes
# URANUS             6.8             -195              NaN     27   Yes
# NEPTUNE            5.4             -200              NaN     14   Yes
# PLUTO              4.7             -225          0.00001      5    No
#
#         MagneticField FirstVisited  FirstMission
# Planet
# MERCURY           Yes   1974-03-29    Mariner 10
# VENUS              No   1962-08-27     Mariner 2
# EARTH             Yes          NaT           NaN
# MOON               No   1959-09-12        Luna 2
# MARS               No   1965-07-15     Mariner 4
# JUPITER           Yes   1973-12-04    Pioneer 10
# SATURN            Yes   1979-09-01    Pioneer 11
# URANUS            Yes   1986-01-24     Voyager 2
# NEPTUNE           Yes   1989-08-25     Voyager 2
# PLUTO             NaN   2015-07-14  New Horizons

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, MERCURY to PLUTO
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Mass             10 non-null     float64
#  1   Diameter         10 non-null     object
#  2   DayLength        10 non-null     float64
#  3   SunDistance      9 non-null      float64
#  4   OrbitPeriod      10 non-null     object
#  5   OrbitVelocity    10 non-null     float64
#  6   MeanTemperature  10 non-null     int64
#  7   SurfacePressure  6 non-null      float64
#  8   Moons            10 non-null     int64
#  9   Rings            10 non-null     object
#  10  MagneticField    9 non-null      object
#  11  FirstVisited     9 non-null      datetime64[ns]
#  12  FirstMission     9 non-null      object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 1.4+ KB

# %%
planets.FirstVisited.dt.year
# Out:
# Planet
# MERCURY    1974.0
# VENUS      1962.0
# EARTH         NaN
# MOON       1959.0
# MARS       1965.0
# JUPITER    1973.0
# SATURN     1979.0
# URANUS     1986.0
# NEPTUNE    1989.0
# PLUTO      2015.0
# Name: FirstVisited, dtype: float64

# %%
2023 - planets.FirstVisited
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\georg\OneDrive\Documentos\VSCode\100DaysPython\100dayspython\notebooks\Ex_Files_Python_Statistics_EssT\Exercise Files\chapter2\02_02\pandas.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/georg/OneDrive/Documentos/VSCode/100DaysPython/100dayspython/notebooks/Ex_Files_Python_Statistics_EssT/Exercise%20Files/chapter2/02_02/pandas.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> 2023 - planets.FirstVisited
#
# File c:\Users\georg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\georg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__rsub__(self, other)
#     196 @unpack_zerodim_and_defer("__rsub__")
#     197 def __rsub__(self, other):
# --> 198     return self._arith_method(other, roperator.rsub)
#
# File c:\Users\georg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6108, in Series._arith_method(self, other, op)
#    6106 def _arith_method(self, other, op):
#    6107     self, other = ops.align_method_SERIES(self, other)
# -> 6108     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\georg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File c:\Users\georg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:224, in arithmetic_op(left, right, op)
#     211 # NB: We assume that extract_array and ensure_wrapped_if_datetimelike
#     212 #  have already been called on `left` and `right`,
#     213 #  and `maybe_prepare_scalar_for_op` has already been called on `right`
#     214 # We need to special-case datetime64/timedelta64 dtypes (e.g. because numpy
#     215 # casts integer dtypes to timedelta64 when operating with timedelta64 - GH#22390)
#     217 if (
#     218     should_extension_dispatch(left, right)
#     219     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)
#     222     # Timedelta/Timestamp and other custom scalars are included in the check
#     223     # because numexpr will fail on it, see GH#31457
# --> 224     res_values = op(left, right)
#     225 else:
#     226     # TODO we should handle EAs consistently and move this check before the if/else
#     227     # (https://github.com/pandas-dev/pandas/issues/41165)
#     228     _bool_arith_check(op, left, right)
#
# File c:\Users\georg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\roperator.py:15, in rsub(left, right)
#      14 def rsub(left, right):
# ---> 15     return right - left
#
# File c:\Users\georg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\datetimelike.py:1458, in DatetimeLikeArrayMixin.__rsub__(self, other)
#    1455     return (-self) + other
#    1457 # We get here with e.g. datetime objects
# -> 1458 return -(self - other)
#
# File c:\Users\georg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\georg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\datetimelike.py:1390, in DatetimeLikeArrayMixin.__sub__(self, other)
#    1386 elif lib.is_integer(other):
#    1387     # This check must come after the check for np.timedelta64
#    1388     # as is_integer returns True for these
#    1389     if not is_period_dtype(self.dtype):
# -> 1390         raise integer_op_not_supported(self)
#    1391     obj = cast("PeriodArray", self)
#    1392     result = obj._addsub_int_array_or_scalar(other * obj.freq.n, operator.sub)
#
# TypeError: Addition/subtraction of integers and integer-arrays with DatetimeArray is no longer supported.  Instead of adding/subtracting `n`, use `n * obj.freq`

# %%
2023 - planets.FirstVisited.dt.year
# Out:
# Planet
# MERCURY    49.0
# VENUS      61.0
# EARTH       NaN
# MOON       64.0
# MARS       58.0
# JUPITER    50.0
# SATURN     44.0
# URANUS     37.0
# NEPTUNE    34.0
# PLUTO       8.0
# Name: FirstVisited, dtype: float64
