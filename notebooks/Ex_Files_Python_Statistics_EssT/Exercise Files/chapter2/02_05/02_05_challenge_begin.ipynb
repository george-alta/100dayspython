# %% [markdown]
# ## Python statistics essential training - 02_05_challenge

# %% [markdown]
# Standard imports

# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
data = pd.read_csv("./tb.csv")

# %%
data.columns
# Out:
# Index(['country', 'year', 'm04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
#        'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
#        'f3544', 'f4554', 'f5564', 'f65', 'fu'],
#       dtype='object')

# %%
data.head()
# Out:
#   country  year  m04  m514  m014  m1524  m2534  m3544  m4554  m5564  ...  f04
# 0      AD  1989  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN  \
# 1      AD  1990  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 2      AD  1991  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 3      AD  1992  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 4      AD  1993  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
#
#    f514  f014  f1524  f2534  f3544  f4554  f5564  f65  fu
# 0   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 1   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 2   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 3   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 4   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
#
# [5 rows x 22 columns]

# %%
dmelt = data.melt(
    ["country", "year"], ['m04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
                          'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
                          'f3544', 'f4554', 'f5564', 'f65', 'fu'], "group", "cases"
)
dmelt.head()
# Out:
#   country  year group  cases
# 0      AD  1989   m04    NaN
# 1      AD  1990   m04    NaN
# 2      AD  1991   m04    NaN
# 3      AD  1992   m04    NaN
# 4      AD  1993   m04    NaN

# %% [markdown]
# removing al NaN

# %%
dmelt.dropna(subset=["cases"], inplace=True)
dmelt.head()
# Out:
#    country  year group  cases
# 15      AD  2005   m04    0.0
# 16      AD  2006   m04    0.0
# 18      AD  2008   m04    0.0
# 42      AE  2006   m04    0.0
# 43      AE  2007   m04    0.0

# %%
dmelt["gender"] = dmelt["group"].str[0].str.upper()
dmelt.head()
# Out:
#    country  year group  cases gender
# 15      AD  2005   m04    0.0      M
# 16      AD  2006   m04    0.0      M
# 18      AD  2008   m04    0.0      M
# 42      AE  2006   m04    0.0      M
# 43      AE  2007   m04    0.0      M

# %%
dmelt["age"] = dmelt["group"].str[1:].str.upper()
dmelt.head()
# Out:
#    country  year group  cases gender age
# 15      AD  2005   m04    0.0      M  04
# 16      AD  2006   m04    0.0      M  04
# 18      AD  2008   m04    0.0      M  04
# 42      AE  2006   m04    0.0      M  04
# 43      AE  2007   m04    0.0      M  04

# %%
dmelt['age'].unique()
# Out:
# array(['04', '514', '014', '1524', '2534', '3544', '4554', '5564', '65',
#        'U'], dtype=object)

# %%
age_groups = {'04': '0-4', '514': '5-14', '014': '0-14', '1524': '15-24', '2534': '25-34', '3544': '35-44', '4554': '45-54', '5564': '55-64', '65': '+65',
              'U': np.nan}

dmelt['age'] = dmelt['age'].replace(age_groups)
dmelt.head()
# Out:
#    country  year group  cases gender  age
# 15      AD  2005   m04    0.0      M  0-4
# 16      AD  2006   m04    0.0      M  0-4
# 18      AD  2008   m04    0.0      M  0-4
# 42      AE  2006   m04    0.0      M  0-4
# 43      AE  2007   m04    0.0      M  0-4

# %%
dmelt = dmelt.drop(columns=["group"])

dmelt.columns
# Out:
# Index(['country', 'year', 'cases', 'gender', 'age'], dtype='object')

# %%
col_order = ['country', 'year', 'age', 'gender', 'cases']
dmelt = dmelt[col_order]
dmelt.head()
# Out:
#    country  year  age gender  cases
# 15      AD  2005  0-4      M    0.0
# 16      AD  2006  0-4      M    0.0
# 18      AD  2008  0-4      M    0.0
# 42      AE  2006  0-4      M    0.0
# 43      AE  2007  0-4      M    0.0

# %%
dmelt.to_csv('./myfinal.csv', index=False)
