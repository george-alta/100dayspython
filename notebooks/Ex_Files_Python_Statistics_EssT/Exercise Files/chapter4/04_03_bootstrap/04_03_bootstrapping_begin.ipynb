# %% [markdown]
# ## Python statistics essential training - 04_03_bootstrapping

# %% [markdown]
# Standard imports

# %%
import math
import io

# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
import scipy.stats
import scipy.optimize
import scipy.spatial

# %%
pop = pd.read_csv("./grades.csv")

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   grade   100 non-null    float64
# dtypes: float64(1)
# memory usage: 932.0 bytes

# %%
pop.head()
# Out:
#       grade
# 0  3.648651
# 1  5.959915
# 2  7.387370
# 3  4.047515
# 4  2.846912

# %%
pop.describe()
# Out:
#             grade
# count  100.000000
# mean     5.508561
# std      1.984988
# min      1.160899
# 25%      3.921372
# 50%      5.688527
# 75%      7.272162
# max      9.120705

# %%
pop.plot.hist(histtype="step")
# Out:
# <Axes: ylabel='Frequency'>

# %%
pop.sample(100, replace=True).describe()
# Out:
#             grade
# count  100.000000
# mean     5.577743
# std      2.016925
# min      1.160899
# 25%      3.921372
# 50%      5.485459
# 75%      7.474421
# max      9.120705

# %%
bootstrap = pd.DataFrame(
    {'meangrade': [pop.sample(100, replace=True).grade.mean() for i in range(1000)]})

# %%
bootstrap.meangrade.hist(histtype='step')
pp.axvline(pop.grade.mean(), color='C1', linestyle=':', label='grade avg')
pp.legend()

# %%
bootstrap.meangrade.quantile(0.025), bootstrap.meangrade.quantile(0.975)
# Out:
# (5.124819212769794, 5.900676358564817)

# %%
n1 = scipy.stats.norm(7.5, 1)
n2 = scipy.stats.norm(4, 1)

x = np.linspace(0, 10, 100)


pp.plot(x, 0.5*n1.pdf(x) + 0.5*n2.pdf(x))

# %%
def draw():
    while True:
        v = n1.rvs() if np.random.rand() < 0.5 else n2.rvs()
        if 0 <= v <= 10:
            return v

# %%
draw()
# Out:
# 6.5725993909980485

# %%
def dataset(n=100):
    return pd.DataFrame({'grade': [draw() for i in range(n)]})

# %%
for i in range(5):
    dataset(100).grade.hist(histtype='step', density=True)

# %%
means = pd.DataFrame(
    {'meangrade': [dataset(100).grade.mean() for i in range(1000)]})

# %%
means.meangrade.hist(histtype='step', label='meangrade')
bootstrap.meangrade.hist(histtype='step', label='bootstrap')
pp.legend()
