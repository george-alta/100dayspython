# %%
import numpy as np
import scipy.stats
import pandas as pd
import matplotlib
import matplotlib.pyplot as pp

import pandas.plotting

from IPython import display
from ipywidgets import interact, widgets

# %matplotlib inline

# %%
data = {'Name': ['Jon', 'Sara', 'Sakura', 'Yo'], 'Age': [20, 18, 27, 50]}
DataFrame = pd.DataFrame(data=data)

# %%
DataFrame.plot.scatter(x='Age', y='Name')
