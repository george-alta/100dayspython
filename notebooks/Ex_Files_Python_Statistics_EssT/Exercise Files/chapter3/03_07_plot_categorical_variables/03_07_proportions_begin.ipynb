# %% [markdown]
# ## Python statistics essential training - 03_07_proportions

# %% [markdown]
# Standard imports

# %%
import numpy as np
import scipy.stats
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as pp

import pandas.plotting

from IPython import display
from ipywidgets import interact, widgets

# %matplotlib inline

# %%
import re
import mailbox
import csv

# %%
smoking = pd.read_csv("whickham.csv")

# %%
smoking['ageGroup'] = pd.cut(smoking.age, [0, 30, 40, 53, 64], labels=[
                             '0-30', '30-40', '40-53', '53-64'])

# %%
bysmoker = smoking.groupby("smoker").outcome.value_counts(normalize=True)

# %%
byage = smoking.groupby(['ageGroup', 'smoker']
                        ).outcome.value_counts(normalize=True)

# %%
bysmoker
# Out:
# smoker  outcome
# No      Alive      0.685792
#         Dead       0.314208
# Yes     Alive      0.761168
#         Dead       0.238832
# Name: proportion, dtype: float64

# %%
byage
# Out:
# ageGroup  smoker  outcome
# 0-30      No      Alive      0.981818
#                   Dead       0.018182
#           Yes     Alive      0.975610
#                   Dead       0.024390
# 30-40     No      Alive      0.955224
#                   Dead       0.044776
#           Yes     Alive      0.940678
#                   Dead       0.059322
# 40-53     No      Alive      0.876106
#                   Dead       0.123894
#           Yes     Alive      0.802395
#                   Dead       0.197605
# 53-64     No      Alive      0.669291
#                   Dead       0.330709
#           Yes     Alive      0.580645
#                   Dead       0.419355
# Name: proportion, dtype: float64

# %%
pp.subplot(1, 2, 1)
smoking.outcome.value_counts().plot(kind='bar', color=['C0', 'C1'])
pp.title('outcome')
pp.subplot(1, 2, 2)
smoking.smoker.value_counts().plot(kind='bar', color=['C3', 'C4'])
pp.title('smoker')
# Out:
# Text(0.5, 1.0, 'smoker')

# %%
pp.subplot(1, 2, 1)
smoking.outcome.value_counts().plot(
    kind='pie', autopct='%1.1f%%', colors=['C0', 'C1'])
pp.title('outcome')
pp.subplot(1, 2, 2)
smoking.smoker.value_counts().plot(
    kind='pie', autopct='%1.1f%%', colors=['C3', 'C4'])
pp.title('smoker')
# Out:
# Text(0.5, 1.0, 'smoker')

# %%
bysmoker
# Out:
# smoker  outcome
# No      Alive      0.685792
#         Dead       0.314208
# Yes     Alive      0.761168
#         Dead       0.238832
# Name: proportion, dtype: float64

# %%
bysmoker.plot(kind="bar")
# Out:
# <Axes: xlabel='smoker,outcome'>

# %%
bysmoker.unstack().plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='smoker'>

# %%
byage.unstack().plot(kind='bar', stacked=True)

pp.legend(loc='upper center', bbox_to_anchor=(1.1, 0.5),
          fancybox=True, ncol=1, title='Outcome')

# %%
byage.unstack().drop("Dead", axis=1).unstack()
# Out:
# outcome      Alive
# smoker          No       Yes
# ageGroup
# 0-30      0.981818  0.975610
# 30-40     0.955224  0.940678
# 40-53     0.876106  0.802395
# 53-64     0.669291  0.580645

# %%
byage2 = byage.unstack().drop('Dead', axis=1).unstack()

byage2.columns = ['no', 'yes']
byage2.columns.name = 'smoker'

# %%
byage2
# Out:
# smoker          no       yes
# ageGroup
# 0-30      0.981818  0.975610
# 30-40     0.955224  0.940678
# 40-53     0.876106  0.802395
# 53-64     0.669291  0.580645

# %%
byage2.plot(kind="bar")
# Out:
# <Axes: xlabel='ageGroup'>
